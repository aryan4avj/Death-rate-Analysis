# %% [markdown]
# # Death Rate analysis of India and its neighbouring countries.

# %% [markdown]
# It is the death-rate data of world from 1960-2018, it is based on death rate per 1,000 people.
#
# Data Link- http://api.worldbank.org/v2/en/indicator/SP.DYN.CDRT.IN?downloadformat=excel
#
# I am analysing data of India and its neighbouring countries, it includes Bangladesh, Bhutan, China, Myanmar, Nepal, Pakistan, Indonesia, Thailand, Sri Lanka, Maldives. i have analysed data from 1960-2018. n
# Research Question:-
# 1. Which Country has the least death rate and state its reason?
# 2. Which Country has improved their countries death rate fastest and what can be the reason for it?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
pd.read_excel?

# %%
df = pd.read_excel('death_rate_excel.xls', sheet_name='Data', skiprows=3)

df = df[(df['Country Name'] == 'India') | (df['Country Name'] == 'Bangladesh') | (df['Country Name'] == 'Bhutan') 
        | (df['Country Name'] == 'China') | (df['Country Name'] == 'Myanmar') | (df['Country Name'] == 'Nepal') 
        | (df['Country Name'] == 'Pakistan') | (df['Country Name'] == 'Indonesia') | (df['Country Name'] == 'Thailand')
        | (df['Country Name'] == 'Sri Lanka') | (df['Country Name'] == 'Maldives') ]

df.drop(["Indicator Name", "Indicator Code", "Country Code"], axis=1, inplace=True)
# df = df[['Country Name', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']]
df = df.set_index('Country Name')
df[:] = df[:].apply(pd.to_numeric, errors='coerce')
df = df.T

plt.style.use('seaborn-colorblind')
df.plot(colormap='Set1', figsize=(12,5), lw=4)
plt.xlabel('Years')
plt.ylabel('Death rate, crude (per 1,000 people)')
plt.title('India and Neighboring Countries Death-rate 1960-2018')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1034">

# %% [markdown]
# ##### In this visualisation, I also followed Cairo's Principle.

# %% [markdown]
# Truthfulness - Here, I am only showing data of India and its neighbouring countries so here we don't consider the world stats and here I also didn't hide any data for favouring any country.
#
# Beauty - Here, I used different colours for representing a country
#
# Functionality - I didn't use any colour grading feature and all because I thought it was not required here.
#
# Insightfulness - Here I show only the relevant data for the representation.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# India is a developing country and all neighbouring countries except China(became developed in 1978) are developing or underdeveloped countries so their death rate is somewhat similar.
#
# 1. After the analysis, we saw that from 1960 to 2018 every country's death has decreased during the period and most of the countries have somewhat similar decreasing rate. But the Maldives has the least death rate in late years, it can be the reason that the Maldives is a small country with very less population so facilities provided by their government can be easily accessible to their country members.
#
# 2. All the countries have similar decreasing curve but China's graph decreased in the 1960s and after that their graph is kinda constant, it can be the reason that China was on an edge on becoming a developed nation so their health conditions were improved very early compared to other countries. So we can say a developed nation's death rate will always be on the lower side.
#
# In the end, I want to conclude that population and development both are important factors in improving the death rate of a country.
